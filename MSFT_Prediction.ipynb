# %% [markdown]
# <a href="https://colab.research.google.com/github/hu921/AI-ML-Projects/blob/master/MSFT_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data source https://finance.yahoo.com/quote/MSFT/history?period1=1616544000&period2=1647993600&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060274
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062427
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063504
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061889
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060812
# ...          ...         ...         ...         ...         ...         ...
# 9077  2022-03-17  293.290009  295.609985  289.369995  295.220001  290.508270
# 9078  2022-03-18  295.369995  301.000000  292.730011  300.429993  295.635132
# 9079  2022-03-21  298.890015  300.140015  294.899994  299.160004  294.385376
# 9080  2022-03-22  299.799988  305.000000  298.769989  304.059998  299.207184
# 9081  2022-03-23  300.510010  303.230011  297.720001  299.489990  294.710144
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9077    30816600
# 9078    43390600
# 9079    28351200
# 9080    27599700
# 9081    25715400
#
# [9082 rows x 7 columns]

# %%
#show close valume
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9077  2022-03-17  295.220001
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
#
# [9082 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9077    2022-03-17
# 9078    2022-03-18
# 9079    2022-03-21
# 9080    2022-03-22
# 9081    2022-03-23
# Name: Date, Length: 9082, dtype: object

# %%
import datetime
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-13-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9077   2022-03-17
# 9078   2022-03-18
# 9079   2022-03-21
# 9080   2022-03-22
# 9081   2022-03-23
# Name: Date, Length: 9082, dtype: datetime64[ns]

# %%
#Show Date as index
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-03-17  295.220001
# 2022-03-18  300.429993
# 2022-03-21  299.160004
# 2022-03-22  304.059998
# 2022-03-23  299.489990
#
# [9082 rows x 1 columns]

# %%
#Visualize the Close prices
import matplotlib.pyplot as p1t
p1t.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 164ms/step - loss: 84895.3047 - mean_absolute_error: 289.6292 - val_loss: 92578.9609 - val_mean_absolute_error: 304.1808
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 84630.1953 - mean_absolute_error: 289.1699 - val_loss: 92305.8516 - val_mean_absolute_error: 303.7316
# Epoch 3/100
# 7/7 [==============================] - 0s 17ms/step - loss: 84339.1875 - mean_absolute_error: 288.6700 - val_loss: 91958.5234 - val_mean_absolute_error: 303.1593
# Epoch 4/100
# 7/7 [==============================] - 0s 17ms/step - loss: 83996.2188 - mean_absolute_error: 288.0694 - val_loss: 91556.9219 - val_mean_absolute_error: 302.4962
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83626.3516 - mean_absolute_error: 287.4291 - val_loss: 91213.6875 - val_mean_absolute_error: 301.9283
# Epoch 6/100
# 7/7 [==============================] - 0s 12ms/step - loss: 83282.5156 - mean_absolute_error: 286.8293 - val_loss: 90757.1406 - val_mean_absolute_error: 301.1713
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 82719.5938 - mean_absolute_error: 285.8434 - val_loss: 89945.3203 - val_mean_absolute_error: 299.8206
# Epoch 8/100
# 7/7 [==============================] - 0s 12ms/step - loss: 81930.8984 - mean_absolute_error: 284.4651 - val_loss: 89136.5703 - val_mean_absolute_error: 298.4688
# Epoch 9/100
# 7/7 [==============================] - 0s 12ms/step - loss: 81146.9141 - mean_absolute_error: 283.0803 - val_loss: 88224.5234 - val_mean_absolute_error: 296.9369
# Epoch 10/100
# 7/7 [==============================] - 0s 12ms/step - loss: 80155.8828 - mean_absolute_error: 281.3162 - val_loss: 86924.8438 - val_mean_absolute_error: 294.7402
# Epoch 11/100
# 7/7 [==============================] - 0s 10ms/step - loss: 78660.9062 - mean_absolute_error: 278.6504 - val_loss: 84764.7422 - val_mean_absolute_error: 291.0527
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 76498.3281 - mean_absolute_error: 274.7387 - val_loss: 82632.9766 - val_mean_absolute_error: 287.3674
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74506.0312 - mean_absolute_error: 271.0915 - val_loss: 80339.9844 - val_mean_absolute_error: 283.3496
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 72166.6094 - mean_absolute_error: 266.7580 - val_loss: 77710.2344 - val_mean_absolute_error: 278.6704
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 69574.8438 - mean_absolute_error: 261.8545 - val_loss: 74802.8750 - val_mean_absolute_error: 273.4043
# Epoch 16/100
# 7/7 [==============================] - 0s 12ms/step - loss: 66763.8281 - mean_absolute_error: 256.4038 - val_loss: 71644.4766 - val_mean_absolute_error: 267.5659
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 63662.1875 - mean_absolute_error: 250.2897 - val_loss: 68142.7266 - val_mean_absolute_error: 260.9401
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 60216.9336 - mean_absolute_error: 243.3230 - val_loss: 64314.6289 - val_mean_absolute_error: 253.4988
# Epoch 19/100
# 7/7 [==============================] - 0s 10ms/step - loss: 56524.7656 - mean_absolute_error: 235.6397 - val_loss: 60257.5508 - val_mean_absolute_error: 245.3662
# Epoch 20/100
# 7/7 [==============================] - 0s 12ms/step - loss: 52632.2148 - mean_absolute_error: 227.1984 - val_loss: 55954.0586 - val_mean_absolute_error: 236.4341
# Epoch 21/100
# 7/7 [==============================] - 0s 13ms/step - loss: 48536.8555 - mean_absolute_error: 217.9764 - val_loss: 51470.2148 - val_mean_absolute_error: 226.7537
# Epoch 22/100
# 7/7 [==============================] - 0s 12ms/step - loss: 44296.7617 - mean_absolute_error: 208.0462 - val_loss: 46881.8516 - val_mean_absolute_error: 216.3998
# Epoch 23/100
# 7/7 [==============================] - 0s 9ms/step - loss: 39986.8750 - mean_absolute_error: 197.4197 - val_loss: 42219.4492 - val_mean_absolute_error: 205.3448
# Epoch 24/100
# 7/7 [==============================] - 0s 13ms/step - loss: 35657.8711 - mean_absolute_error: 186.1105 - val_loss: 37548.9336 - val_mean_absolute_error: 193.6387
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 31322.7520 - mean_absolute_error: 174.1084 - val_loss: 32799.9492 - val_mean_absolute_error: 180.9610
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 26989.5566 - mean_absolute_error: 161.1332 - val_loss: 28244.1230 - val_mean_absolute_error: 167.9022
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - loss: 22956.3184 - mean_absolute_error: 148.0525 - val_loss: 23973.6973 - val_mean_absolute_error: 154.6633
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 19177.3125 - mean_absolute_error: 134.7648 - val_loss: 20016.4727 - val_mean_absolute_error: 141.2923
# Epoch 29/100
# 7/7 [==============================] - 0s 10ms/step - loss: 15723.3047 - mean_absolute_error: 121.3637 - val_loss: 16402.3633 - val_mean_absolute_error: 127.8648
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 12671.1562 - mean_absolute_error: 107.9148 - val_loss: 13156.4258 - val_mean_absolute_error: 114.4704
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9987.5869 - mean_absolute_error: 94.6512 - val_loss: 10343.6953 - val_mean_absolute_error: 101.4432
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7687.5605 - mean_absolute_error: 81.8223 - val_loss: 7963.1982 - val_mean_absolute_error: 88.9395
# Epoch 33/100
# 7/7 [==============================] - 0s 12ms/step - loss: 5850.9004 - mean_absolute_error: 69.5304 - val_loss: 5997.9482 - val_mean_absolute_error: 77.1036
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4374.9312 - mean_absolute_error: 57.9227 - val_loss: 4319.3726 - val_mean_absolute_error: 65.3167
# Epoch 35/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3141.7344 - mean_absolute_error: 46.7268 - val_loss: 3016.1096 - val_mean_absolute_error: 54.4347
# Epoch 36/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2318.3984 - mean_absolute_error: 38.7889 - val_loss: 2116.5637 - val_mean_absolute_error: 45.4262
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1763.0637 - mean_absolute_error: 33.9915 - val_loss: 1403.3259 - val_mean_absolute_error: 36.7471
# Epoch 38/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1391.7170 - mean_absolute_error: 31.1125 - val_loss: 958.9540 - val_mean_absolute_error: 30.0997
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1196.0791 - mean_absolute_error: 29.2029 - val_loss: 686.0609 - val_mean_absolute_error: 25.1614
# Epoch 40/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1088.8937 - mean_absolute_error: 27.9727 - val_loss: 521.0739 - val_mean_absolute_error: 21.6359
# Epoch 41/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1042.5476 - mean_absolute_error: 27.3822 - val_loss: 417.1420 - val_mean_absolute_error: 19.0835
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1018.5062 - mean_absolute_error: 26.9665 - val_loss: 346.1324 - val_mean_absolute_error: 17.1222
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.0389 - mean_absolute_error: 26.8826 - val_loss: 293.7728 - val_mean_absolute_error: 15.5348
# Epoch 44/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1009.0693 - mean_absolute_error: 26.8409 - val_loss: 277.9950 - val_mean_absolute_error: 15.0610
# Epoch 45/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1008.8898 - mean_absolute_error: 26.8430 - val_loss: 244.4334 - val_mean_absolute_error: 13.9888
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1009.7650 - mean_absolute_error: 26.8672 - val_loss: 245.5174 - val_mean_absolute_error: 14.0247
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.3818 - mean_absolute_error: 26.8597 - val_loss: 252.2504 - val_mean_absolute_error: 14.2462
# Epoch 48/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1008.3406 - mean_absolute_error: 26.8459 - val_loss: 264.2262 - val_mean_absolute_error: 14.6317
# Epoch 49/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1006.8937 - mean_absolute_error: 26.8078 - val_loss: 274.9057 - val_mean_absolute_error: 14.9668
# Epoch 50/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1005.5710 - mean_absolute_error: 26.8014 - val_loss: 269.3603 - val_mean_absolute_error: 14.7949
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1004.4421 - mean_absolute_error: 26.7833 - val_loss: 267.3438 - val_mean_absolute_error: 14.7322
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1003.8796 - mean_absolute_error: 26.7772 - val_loss: 274.2650 - val_mean_absolute_error: 14.9485
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1002.8665 - mean_absolute_error: 26.7698 - val_loss: 282.7555 - val_mean_absolute_error: 15.2090
# Epoch 54/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1003.4409 - mean_absolute_error: 26.7767 - val_loss: 285.5549 - val_mean_absolute_error: 15.2947
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1000.5301 - mean_absolute_error: 26.7433 - val_loss: 282.8233 - val_mean_absolute_error: 15.2132
# Epoch 56/100
# 7/7 [==============================] - 0s 12ms/step - loss: 998.2227 - mean_absolute_error: 26.6993 - val_loss: 277.9034 - val_mean_absolute_error: 15.0641
# Epoch 57/100
# 7/7 [==============================] - 0s 11ms/step - loss: 994.0560 - mean_absolute_error: 26.6512 - val_loss: 310.4379 - val_mean_absolute_error: 16.0861
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 977.0221 - mean_absolute_error: 26.4753 - val_loss: 265.1462 - val_mean_absolute_error: 14.6817
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 976.0942 - mean_absolute_error: 26.4004 - val_loss: 276.2160 - val_mean_absolute_error: 15.0309
# Epoch 60/100
# 7/7 [==============================] - 0s 12ms/step - loss: 954.3329 - mean_absolute_error: 26.1086 - val_loss: 377.1791 - val_mean_absolute_error: 18.0705
# Epoch 61/100
# 7/7 [==============================] - 0s 13ms/step - loss: 968.4957 - mean_absolute_error: 26.2177 - val_loss: 277.1490 - val_mean_absolute_error: 15.0786
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 934.4093 - mean_absolute_error: 25.8525 - val_loss: 305.3501 - val_mean_absolute_error: 15.9808
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 907.9802 - mean_absolute_error: 25.5376 - val_loss: 415.4227 - val_mean_absolute_error: 19.1342
# Epoch 64/100
# 7/7 [==============================] - 0s 11ms/step - loss: 916.7864 - mean_absolute_error: 25.6620 - val_loss: 264.3507 - val_mean_absolute_error: 14.7071
# Epoch 65/100
# 7/7 [==============================] - 0s 10ms/step - loss: 899.4603 - mean_absolute_error: 25.2596 - val_loss: 344.5110 - val_mean_absolute_error: 17.2140
# Epoch 66/100
# 7/7 [==============================] - 0s 10ms/step - loss: 860.8318 - mean_absolute_error: 24.8233 - val_loss: 320.0660 - val_mean_absolute_error: 16.4981
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 855.3724 - mean_absolute_error: 24.6314 - val_loss: 317.0699 - val_mean_absolute_error: 16.4320
# Epoch 68/100
# 7/7 [==============================] - 0s 12ms/step - loss: 825.8685 - mean_absolute_error: 24.2601 - val_loss: 276.5763 - val_mean_absolute_error: 15.1612
# Epoch 69/100
# 7/7 [==============================] - 0s 12ms/step - loss: 801.8437 - mean_absolute_error: 23.8646 - val_loss: 227.1429 - val_mean_absolute_error: 13.5550
# Epoch 70/100
# 7/7 [==============================] - 0s 12ms/step - loss: 779.6545 - mean_absolute_error: 23.5896 - val_loss: 305.8258 - val_mean_absolute_error: 16.1472
# Epoch 71/100
# 7/7 [==============================] - 0s 9ms/step - loss: 762.4172 - mean_absolute_error: 23.2774 - val_loss: 202.5581 - val_mean_absolute_error: 12.7003
# Epoch 72/100
# 7/7 [==============================] - 0s 14ms/step - loss: 753.8013 - mean_absolute_error: 23.1056 - val_loss: 260.1616 - val_mean_absolute_error: 14.7018
# Epoch 73/100
# 7/7 [==============================] - 0s 12ms/step - loss: 717.0950 - mean_absolute_error: 22.6290 - val_loss: 316.0009 - val_mean_absolute_error: 16.5256
# Epoch 74/100
# 7/7 [==============================] - 0s 12ms/step - loss: 677.8318 - mean_absolute_error: 21.9225 - val_loss: 174.5557 - val_mean_absolute_error: 11.6931
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 638.4428 - mean_absolute_error: 21.2017 - val_loss: 346.6306 - val_mean_absolute_error: 17.5118
# Epoch 76/100
# 7/7 [==============================] - 0s 12ms/step - loss: 608.2279 - mean_absolute_error: 20.7553 - val_loss: 76.0053 - val_mean_absolute_error: 7.0352
# Epoch 77/100
# 7/7 [==============================] - 0s 13ms/step - loss: 631.2925 - mean_absolute_error: 21.0716 - val_loss: 302.9426 - val_mean_absolute_error: 16.2553
# Epoch 78/100
# 7/7 [==============================] - 0s 11ms/step - loss: 542.6083 - mean_absolute_error: 19.5901 - val_loss: 251.5273 - val_mean_absolute_error: 14.5907
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 564.7930 - mean_absolute_error: 19.4296 - val_loss: 77.6333 - val_mean_absolute_error: 7.1435
# Epoch 80/100
# 7/7 [==============================] - 0s 10ms/step - loss: 523.1375 - mean_absolute_error: 19.2289 - val_loss: 105.4064 - val_mean_absolute_error: 8.6515
# Epoch 81/100
# 7/7 [==============================] - 0s 10ms/step - loss: 487.1695 - mean_absolute_error: 18.5326 - val_loss: 306.4951 - val_mean_absolute_error: 16.4690
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 439.9465 - mean_absolute_error: 17.5827 - val_loss: 191.8464 - val_mean_absolute_error: 12.5071
# Epoch 83/100
# 7/7 [==============================] - 0s 12ms/step - loss: 387.5226 - mean_absolute_error: 16.2799 - val_loss: 52.9071 - val_mean_absolute_error: 5.7802
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 407.0630 - mean_absolute_error: 17.1055 - val_loss: 206.1100 - val_mean_absolute_error: 13.1541
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 349.9522 - mean_absolute_error: 15.8392 - val_loss: 139.8068 - val_mean_absolute_error: 10.4457
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 303.3797 - mean_absolute_error: 14.2799 - val_loss: 74.4913 - val_mean_absolute_error: 7.0930
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 268.3752 - mean_absolute_error: 13.3883 - val_loss: 57.0017 - val_mean_absolute_error: 6.0797
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 246.0529 - mean_absolute_error: 12.8669 - val_loss: 53.5114 - val_mean_absolute_error: 5.9071
# Epoch 89/100
# 7/7 [==============================] - 0s 12ms/step - loss: 220.0769 - mean_absolute_error: 11.9396 - val_loss: 48.2324 - val_mean_absolute_error: 5.6295
# Epoch 90/100
# 7/7 [==============================] - 0s 11ms/step - loss: 188.7387 - mean_absolute_error: 11.0161 - val_loss: 75.3225 - val_mean_absolute_error: 7.2053
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 150.3191 - mean_absolute_error: 9.8603 - val_loss: 31.5474 - val_mean_absolute_error: 4.9201
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 130.3566 - mean_absolute_error: 8.8110 - val_loss: 31.9484 - val_mean_absolute_error: 4.9617
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 104.9450 - mean_absolute_error: 7.7533 - val_loss: 36.2084 - val_mean_absolute_error: 5.1678
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 85.0883 - mean_absolute_error: 6.8010 - val_loss: 32.2188 - val_mean_absolute_error: 4.9700
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 71.1878 - mean_absolute_error: 6.1819 - val_loss: 30.1157 - val_mean_absolute_error: 4.8239
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 62.6318 - mean_absolute_error: 5.9779 - val_loss: 33.2853 - val_mean_absolute_error: 4.8477
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 53.7920 - mean_absolute_error: 5.5010 - val_loss: 32.7535 - val_mean_absolute_error: 4.8429
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 49.3769 - mean_absolute_error: 5.5210 - val_loss: 30.2413 - val_mean_absolute_error: 4.8158
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 48.6946 - mean_absolute_error: 5.4612 - val_loss: 43.5792 - val_mean_absolute_error: 5.1672
# Epoch 100/100
# 7/7 [==============================] - 0s 9ms/step - loss: 39.8819 - mean_absolute_error: 4.8614 - val_loss: 50.9509 - val_mean_absolute_error: 5.5614

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
